# %% [markdown]
# # Ensemble Techniques

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv("D:\projects\ML Projects datasets\Churn_Modelling.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df=data.drop(['RowNumber','CustomerId','Surname'], axis=1)

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
geography = pd.get_dummies(df['Geography'], drop_first=True)

# %%
male=pd.get_dummies(df['Gender'], drop_first=True)

# %%
new_data=pd.concat([df , geography ,male], axis=1)

# %%
new_data
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
# ...

# %%
dataset=new_data.drop(['Geography','Gender'], axis=1)

# %%
dataset
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Germany  Spain  Male
# 0                  1        101348.88       1        0      0     0
# ...

# %%
dataset.columns
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Germany', 'Spain',
#        'Male'],
#       dtype='object')

# %%
dfset=dataset[['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
       'IsActiveMember', 'EstimatedSalary','Germany', 'Spain',
       'Male', 'Exited']]

# %%
dfset
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male  Exited
# 0                  1        101348.88        0      0     0       1
# ...

# %%
dfset.isnull().sum()
# Out:
# CreditScore        0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Germany            0
# Spain              0
# Male               0
# Exited             0
# dtype: int64

# %%
dfset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Age              10000 non-null  int64
#  2   Tenure           10000 non-null  int64
#  3   Balance          10000 non-null  float64
#  4   NumOfProducts    10000 non-null  int64
#  5   HasCrCard        10000 non-null  int64
#  6   IsActiveMember   10000 non-null  int64
#  7   EstimatedSalary  10000 non-null  float64
#  8   Germany          10000 non-null  uint8
#  9   Spain            10000 non-null  uint8
#  10  Male             10000 non-null  uint8
#  11  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), uint8(3)
# memory usage: 732.5 KB

# %%
dfset.corr()
# Out:
#                  CreditScore       Age    Tenure   Balance  NumOfProducts  \
# CreditScore         1.000000 -0.003965  0.000842  0.006268       0.012238
# Age                -0.003965  1.000000 -0.009997  0.028308      -0.030680
# Tenure              0.000842 -0.009997  1.000000 -0.012254       0.013444
# Balance             0.006268  0.028308 -0.012254  1.000000      -0.304180
# NumOfProducts       0.012238 -0.030680  0.013444 -0.304180       1.000000
# HasCrCard          -0.005458 -0.011721  0.022583 -0.014858       0.003183
# IsActiveMember      0.025651  0.085472 -0.028362 -0.010084       0.009612
# EstimatedSalary    -0.001384 -0.007201  0.007784  0.012797       0.014204
# Germany             0.005538  0.046897 -0.000567  0.401110      -0.010419
# Spain               0.004780 -0.001685  0.003868 -0.134892       0.009039
# Male               -0.002857 -0.027544  0.014733  0.012087      -0.021859
# Exited             -0.027094  0.285323 -0.014001  0.118533      -0.047820
#
# ...

# %%
dfset.tail()
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male  Exited
# 9995               0         96270.64        0      0     1       0
# 9996               1        101699.77        0      0     1       0
# 9997               1         42085.58        0      0     0       1
# 9998               0         92888.52        1      0     1       1
# 9999               0         38190.78        0      0     0       0

# %%
dfset.shape
# Out:
# (10000, 12)

# %%
#sns.pairplot(dfset, hue='Tenure')

# %%
dfset.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain  Male  Exited
# 0               1        101348.88        0      0     0       1
# 1               1        112542.58        0      1     0       0
# 2               0        113931.57        0      0     0       1
# 3               0         93826.63        0      0     0       0
# 4               1         79084.10        0      1     0       0

# %%
x = dfset.iloc[:,0:11]
y = dfset.iloc[:, 11]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=100)

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rfc.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test
# Out:
# 9394    0
# 898     1
# 2398    0
# 5906    0
# 2343    0
#        ..
# 1037    0
# 2899    0
# 9549    0
# 2740    0
# 6690    0
# Name: Exited, Length: 2000, dtype: int64

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

# %%
cr=classification_report(y_test,y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      1595
#            1       0.73      0.51      0.60       405
#
#     accuracy                           0.86      2000
#    macro avg       0.81      0.73      0.76      2000
# weighted avg       0.85      0.86      0.85      2000

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[1518,   77],
#        [ 197,  208]], dtype=int64)

# %%
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.863

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada=AdaBoostClassifier(learning_rate=0.01)

# %%
ada.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(learning_rate=0.01)

# %%
ada_pred=ada.predict(x_test)

# %%
ada_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
ada_cr=classification_report(y_test,ada_pred)
print(ada_cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90      1595
#            1       1.00      0.08      0.15       405
#
#     accuracy                           0.81      2000
#    macro avg       0.91      0.54      0.52      2000
# weighted avg       0.85      0.81      0.74      2000

# %%
ada_cm=confusion_matrix(y_test,ada_pred)
ada_cm
# Out:
# array([[1595,    0],
#        [ 372,   33]], dtype=int64)

# %%
ada_score=accuracy_score(y_test,ada_pred)
ada_score
# Out:
# 0.814

# %% [markdown]
# # gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gd=GradientBoostingClassifier()

# %%
gd.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
gd_pred = gd.predict(x_test)
gd_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
gd_cr=classification_report(y_test,gd_pred)
print(gd_cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      1595
#            1       0.75      0.52      0.61       405
#
#     accuracy                           0.87      2000
#    macro avg       0.82      0.74      0.77      2000
# weighted avg       0.86      0.87      0.86      2000

# %%
gd_cm=confusion_matrix(y_test,gd_pred)
gd_cm
# Out:
# array([[1523,   72],
#        [ 194,  211]], dtype=int64)

# %%
gd_score=accuracy_score(y_test,gd_pred)
gd_score
# Out:
# 0.867
